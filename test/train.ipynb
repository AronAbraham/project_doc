# %%
import tensorflow as tf
from tensorflow.keras import models,layers
import matplotlib.pyplot as plt
import numpy as np
from sklearn.externals import joblib
from PIL import Image

# %%
isize=256
bsize=32
channel=3
epochs=30

# %%
dataset=tf.keras.preprocessing.image_dataset_from_directory(
"photos",shuffle=True,image_size=(isize,isize),batch_size=bsize)
# Out:
# Found 2610 files belonging to 4 classes.

# %%
x=dataset.class_names

# %%
x[0]
# Out:
# 'Potato___Early_blight'

# %%
plt.figure(figsize=(10 ,10))
for image_batch, label_batch in dataset.take(1):
    for i in range(12):
        ax=plt.subplot(3,4,i+1)
        plt.imshow(image_batch[i].numpy().astype("uint8"))
        plt.title(x[label_batch[i]])
        plt.axis('off')

# %%
#80% ==> training
#20% ==> 10% validation, 10% test
p=len(dataset)*0.8
display(p)
# Out:
# 65.60000000000001

# %%
trainds=dataset.take(54)
testds=dataset.skip(54)
len(dataset)*0.1
# Out:
# 8.200000000000001

# %%
valds=testds.take(6)
len(valds)
# Out:
# 6

# %%
testds=dataset.skip(6)

# %%
def get_dataset_partitions(ds,train_split=0.8,val_split=0.1,test_split=0.1,shuffle=True,shuffle_size=10000):
    ds_size=len(ds)
    if shuffle:
        ds=ds.shuffle(shuffle_size,seed=12)
    train_size=int(train_split*ds_size)
    val_size=int(val_split*ds_size)
    
    train_ds=ds.take(train_size)
    ds.skip(train_size)
    val_ds=ds.take(val_size)
    ds.skip(val_size)
    test_ds=ds.take(val_size)
    return train_ds,val_ds,test_ds

# %%
train_ds, val_ds, test_ds=get_dataset_partitions(dataset)

# %%
train_ds=train_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)
val_ds=val_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)
test_ds=test_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)

# %%
rr=tf.keras.Sequential([layers.experimental.preprocessing.Resizing(isize,isize),
                     layers.experimental.preprocessing.Rescaling(1.0/255)])

# %%
da=tf.keras.Sequential([layers.experimental.preprocessing.RandomFlip("horizontal_and_vertical"),
                     layers.experimental.preprocessing.RandomRotation(0.2)])

# %%
#Build the CNN model
input_shape=(bsize, isize, isize, channel)
model = models.Sequential([
    rr,
    da,
    layers.Conv2D(32, (3, 3), activation='relu', input_shape=(isize, isize, channel)),
    layers.MaxPooling2D((2, 2)),
    layers.Dropout(0.5),
    layers.Conv2D(64, (3, 3), activation='relu', padding='same'),
    layers.MaxPooling2D((2, 2)),
    layers.Dropout(0.5),
    layers.Conv2D(64, (3, 3), activation='relu', padding='same'),
    layers.MaxPooling2D((2, 2)),
    layers.Conv2D(64, (3, 3), activation='relu', padding='same'),
    layers.MaxPooling2D((2, 2)),
    layers.Conv2D(64, (3, 3), activation='relu', padding='same'),
    layers.MaxPooling2D((2, 2)),
    layers.Conv2D(64, (3, 3), activation='relu', padding='same'),
    layers.MaxPooling2D((2, 2)),
    layers.Flatten(),
    layers.Dense(64, activation='relu'),
    layers.Dense(len(dataset.class_names), activation='softmax')
])
model.build(input_shape=input_shape)
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential (Sequential)     (32, 256, 256, 3)         0
#
#  sequential_1 (Sequential)   (32, 256, 256, 3)         0
#
#  conv2d (Conv2D)             (32, 254, 254, 32)        896
#
#  max_pooling2d (MaxPooling2  (32, 127, 127, 32)        0
#  D)
#
#  dropout (Dropout)           (32, 127, 127, 32)        0
#
#  conv2d_1 (Conv2D)           (32, 127, 127, 64)        18496
#
#  max_pooling2d_1 (MaxPoolin  (32, 63, 63, 64)          0
#  g2D)
#
#  dropout_1 (Dropout)         (32, 63, 63, 64)          0
#
#  conv2d_2 (Conv2D)           (32, 63, 63, 64)          36928
#
#  max_pooling2d_2 (MaxPoolin  (32, 31, 31, 64)          0
#  g2D)
#
#  conv2d_3 (Conv2D)           (32, 31, 31, 64)          36928
#
#  max_pooling2d_3 (MaxPoolin  (32, 15, 15, 64)          0
#  g2D)
#
#  conv2d_4 (Conv2D)           (32, 15, 15, 64)          36928
#
#  max_pooling2d_4 (MaxPoolin  (32, 7, 7, 64)            0
#  g2D)
#
#  conv2d_5 (Conv2D)           (32, 7, 7, 64)            36928
#
#  max_pooling2d_5 (MaxPoolin  (32, 3, 3, 64)            0
#  g2D)
#
#  flatten (Flatten)           (32, 576)                 0
#
#  dense (Dense)               (32, 64)                  36928
#
#  dense_1 (Dense)             (32, 4)                   260
#
# =================================================================
# Total params: 204292 (798.02 KB)
# Trainable params: 204292 (798.02 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# # Compile the model
model.compile(optimizer='adam',
               loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
               metrics=['accuracy'])

# %%
# # Train the model
history = model.fit(train_ds,epochs=epochs,batch_size=bsize,verbose=1, validation_data=val_ds)
# Out:
# Epoch 1/30
# C:\Users\mathe_thld2cd\AppData\Roaming\Python\Python311\site-packages\keras\src\backend.py:5729: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a Softmax activation and thus does not represent logits. Was this intended?
#   output, from_logits = _get_logits(
# 65/65 [==============================] - 149s 2s/step - loss: 1.2128 - accuracy: 0.4313 - val_loss: 1.2593 - val_accuracy: 0.4766
# Epoch 2/30
# 65/65 [==============================] - 110s 2s/step - loss: 0.8486 - accuracy: 0.6592 - val_loss: 0.6914 - val_accuracy: 0.7422
# Epoch 3/30
# 65/65 [==============================] - 110s 2s/step - loss: 0.5100 - accuracy: 0.8040 - val_loss: 0.5239 - val_accuracy: 0.8438
# Epoch 4/30
# 65/65 [==============================] - 113s 2s/step - loss: 0.4170 - accuracy: 0.8388 - val_loss: 0.7220 - val_accuracy: 0.6562
# Epoch 5/30
# 65/65 [==============================] - 99s 2s/step - loss: 0.3264 - accuracy: 0.8727 - val_loss: 0.4873 - val_accuracy: 0.8125
# Epoch 6/30
# 65/65 [==============================] - 98s 2s/step - loss: 0.2781 - accuracy: 0.8882 - val_loss: 0.2636 - val_accuracy: 0.9141
# Epoch 7/30
# 65/65 [==============================] - 99s 2s/step - loss: 0.2679 - accuracy: 0.9027 - val_loss: 0.6144 - val_accuracy: 0.7344
# Epoch 8/30
# 65/65 [==============================] - 104s 2s/step - loss: 0.1661 - accuracy: 0.9400 - val_loss: 0.2085 - val_accuracy: 0.9141
# Epoch 9/30
# 65/65 [==============================] - 102s 2s/step - loss: 0.1176 - accuracy: 0.9598 - val_loss: 0.2717 - val_accuracy: 0.8867
# Epoch 10/30
# 65/65 [==============================] - 99s 2s/step - loss: 0.1203 - accuracy: 0.9545 - val_loss: 0.0960 - val_accuracy: 0.9648
# Epoch 11/30
# 65/65 [==============================] - 100s 2s/step - loss: 0.0964 - accuracy: 0.9627 - val_loss: 0.0656 - val_accuracy: 0.9805
# Epoch 12/30
# 65/65 [==============================] - 1281s 20s/step - loss: 0.1019 - accuracy: 0.9627 - val_loss: 0.1233 - val_accuracy: 0.9609
# Epoch 13/30
# 65/65 [==============================] - 124s 2s/step - loss: 0.0699 - accuracy: 0.9739 - val_loss: 0.0700 - val_accuracy: 0.9805
# Epoch 14/30
# 65/65 [==============================] - 111s 2s/step - loss: 0.0804 - accuracy: 0.9685 - val_loss: 0.0918 - val_accuracy: 0.9688
# Epoch 15/30
# 65/65 [==============================] - 111s 2s/step - loss: 0.0730 - accuracy: 0.9777 - val_loss: 0.1371 - val_accuracy: 0.9609
# Epoch 16/30
# 65/65 [==============================] - 109s 2s/step - loss: 0.0641 - accuracy: 0.9724 - val_loss: 0.2610 - val_accuracy: 0.9141
# Epoch 17/30
# 65/65 [==============================] - 106s 2s/step - loss: 0.0588 - accuracy: 0.9773 - val_loss: 0.0558 - val_accuracy: 0.9766
# Epoch 18/30
# 65/65 [==============================] - 110s 2s/step - loss: 0.0579 - accuracy: 0.9773 - val_loss: 0.0975 - val_accuracy: 0.9688
# Epoch 19/30
# 65/65 [==============================] - 103s 2s/step - loss: 0.0489 - accuracy: 0.9864 - val_loss: 0.1596 - val_accuracy: 0.9375
# Epoch 20/30
# 65/65 [==============================] - 108s 2s/step - loss: 0.0478 - accuracy: 0.9826 - val_loss: 0.0346 - val_accuracy: 0.9922
# Epoch 21/30
# 65/65 [==============================] - 106s 2s/step - loss: 0.0617 - accuracy: 0.9782 - val_loss: 0.0915 - val_accuracy: 0.9648
# Epoch 22/30
# 65/65 [==============================] - 104s 2s/step - loss: 0.0499 - accuracy: 0.9811 - val_loss: 0.0313 - val_accuracy: 0.9961
# Epoch 23/30
# 65/65 [==============================] - 113s 2s/step - loss: 0.0736 - accuracy: 0.9753 - val_loss: 0.3401 - val_accuracy: 0.8750
# Epoch 24/30
# 65/65 [==============================] - 113s 2s/step - loss: 0.0558 - accuracy: 0.9816 - val_loss: 0.0452 - val_accuracy: 0.9883
# Epoch 25/30
# 65/65 [==============================] - 111s 2s/step - loss: 0.0851 - accuracy: 0.9705 - val_loss: 0.0362 - val_accuracy: 0.9883
# Epoch 26/30
# 65/65 [==============================] - 121s 2s/step - loss: 0.0665 - accuracy: 0.9748 - val_loss: 0.0603 - val_accuracy: 0.9844
# Epoch 27/30
# 65/65 [==============================] - 116s 2s/step - loss: 0.0358 - accuracy: 0.9879 - val_loss: 0.0327 - val_accuracy: 0.9844
# Epoch 28/30
# 65/65 [==============================] - 113s 2s/step - loss: 0.0459 - accuracy: 0.9850 - val_loss: 0.1480 - val_accuracy: 0.9570
# Epoch 29/30
# 65/65 [==============================] - 106s 2s/step - loss: 0.0298 - accuracy: 0.9889 - val_loss: 0.1062 - val_accuracy: 0.9648
# Epoch 30/30
# 65/65 [==============================] - 129s 2s/step - loss: 0.0400 - accuracy: 0.9855 - val_loss: 0.0780 - val_accuracy: 0.9688

# %% [markdown]
# scores=model.evaluate(test_ds)

# %%
# # Evaluate the model
test_loss, test_acc = model.evaluate(test_ds)
print("Test Loss:", test_loss)
print("Test Accuracy:", test_acc)
# Out:
# 8/8 [==============================] - 17s 320ms/step - loss: 0.0729 - accuracy: 0.9688
# Test Loss: 0.07286719977855682
# Test Accuracy: 0.96875

# %%
# model.save('healplant.keras')

# %%
plt.plot(range(epochs),history.history['accuracy'])

# %%
for images_batch, labels_batch in test_ds.take(1):
 first_image = images_batch[0].numpy() .astype('uint8')
 first_label = labels_batch[0].numpy()
 print("first image to predict")
 plt. imshow(first_image)
 print("actual label:",x[first_label])
 batch_prediction = model. predict (images_batch)
 print(x[np.argmax(batch_prediction[0])])
# Out:
# first image to predict
# actual label: Potato___Late_blight
# 1/1 [==============================] - 1s 526ms/step
# Potato___Late_blight

# %%
joblib.dump(model,'helpplant')
# Out:
# ['helpplant']

# %%
# Load the model
loaded_model = joblib.load('helpplant')

# Open and load the image using Pillow
image = Image.open('h.jpg')

# Check if the image was loaded successfully
if image is not None:
    # Resize the image to the desired size (e.g., 224x224)
    image = image.resize((256, 256))

    # Convert the image to float32
    image = np.array(image, dtype=np.float32)

    # Normalize pixel values to the range [0, 1]
    image /= 255.0

    # Make predictions using the loaded model
    predictions = loaded_model.predict(np.expand_dims(image, axis=0))

    # Print the predictions or perform further actions
    print(x[np.argmax(predictions)])
    #print(predictions)
else:
    print("Failed to load the image.")
# Out:
# 1/1 [==============================] - 0s 279ms/step
# Healthy
